# %% [markdown]
# # Introduction to Keras
#
# ## What is Keras?
# Keras is a deep-learning framework that provides a convenient way to define and train almost any kind of deep-learning model. It is written in Python and can be run on top of TensorFlow, CNTK, or Theano. You are free to use it in commercial projects since it is distributed under the MIT license. One of the most important characteristics of Keras is its user-friendly API. You could develop a state of art deep learning model in no time.
#
# ## The Model class
#
# The core data structure of Keras is the Model class. It is found under keras.models that gives you two ways to define models: The Sequential class and the Model class. The Sequential class builds the network layer by layer in a sequential order. The Model class allows for more complex network structures. In this exercise you will use the Sequential class.

# %% [markdown]
# # Setup
#
# We start with importing all packages we will need.

# %%
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# Import keras modules
from keras.models import Sequential
from keras.layers import Dense
from keras.initializers import random_normal
import tensorflow as tf
import keras as keras

print('keras version:', keras.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# keras version: 2.14.0
# tensorflow version: 2.14.0

# %% [markdown]
# # Load the data
#
# The `make_moons()` method is used to generate data with a bit of noise.
# Divide this data into the train and test sets.
# [Documentation on make_moons()](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html)
#
# Look [here](https://scikit-learn.org/stable/modules/classes.html#) for the correct function to split the data.

# %%
np.random.seed(0)
X, Y = make_moons(500, noise=0.2)

# TODO divide the data in train and test sets
X_train, X_test, Y_train, Y_test =  train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# Let's  a [Mathplotlib Scatter plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) to visualize the generated training data.

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, s=40, cmap=plt.cm.Spectral)

# %% [markdown]
# Let's create a second [Mathplotlib Scatter plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) to visualize the generated test data.

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test, s=40, cmap=plt.cm.Spectral)

# %% [markdown]
# You can also compare it with the complete (undivided) generate data set.

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y, s=40, cmap=plt.cm.Spectral)

# %% [markdown]
# Inspect a few data points to get some insights into the generated data.
# The X data points will be the input of the neural network.
# The Y data points is the expected output.

# %%
print(X[0:5]) # print the first 5 elements in X
print()
print(Y[0:5]) # print the first 5 elements in Y
# Out:
# [[ 0.30240233  0.89623817]
#  [-0.38598275  0.48730979]
#  [ 0.19020931  0.11325428]
#  [ 1.71457157 -0.11033049]
#  [ 1.96706272 -0.5158008 ]]
#
# [0 1 1 1 1]

# %% [markdown]
# Inspect the train and test data points.

# %%
# Insert your code here.

# %% [markdown]
# ## Define Keras Model
#
# Here is a schematic representation of the methods in the Model class we will use.
#
# ![keras_model_lifecycle.jpg](data:image/jpeg;base64,...)
#
# Define the number of input nodes (input_dim) and the number of output node (output_dim).

# %%
input_dim = 2 # SET CORRECT VALUE
output_dim = 1 # SET CORRECT VALUE

# %% [markdown]
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
# You start off with one hidden layer. In the hidden layer(s) you use a ReLU activation function. In the output layer you use a sigmoid activation function.
# Documentation on the Dense layers you add to the model can be found [here](https://keras.io/api/layers/core_layers/dense/).
# Use 32 as the amount of units.

# %%
model = Sequential()
model.add(Dense(32, input_dim=input_dim, activation='relu'))
model.add(Dense(output_dim, activation='sigmoid'))

# %% [markdown]
# Here is a short summary of the network you created.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                96
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 129 (516.00 Byte)
# Trainable params: 129 (516.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next step is to `compile` the model you created.
# Documentation on the compile method can be found [here](https://keras.io/api/models/model_training_apis/).
#
# Use the following configuration
# 1.   loss: 'binary_crossentropy'
# 2.   optimizer: 'sgd'
# 3.   metrics: ['accuracy']

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# Now it's time to train the model for a fixed number of 300 epochs. Find out how the `fit()` method works.

# %%
hist = model.fit(X_train, Y_train, epochs=300, verbose=1)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 1s 7ms/step - loss: 0.7099 - accuracy: 0.4250
# Epoch 2/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.5500
# Epoch 3/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6623 - accuracy: 0.6450
# Epoch 4/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6426 - accuracy: 0.7250
# Epoch 5/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6254 - accuracy: 0.7700
# Epoch 6/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6097 - accuracy: 0.7850
# Epoch 7/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5960 - accuracy: 0.8400
# Epoch 8/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5827 - accuracy: 0.8575
# Epoch 9/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5705 - accuracy: 0.8475
# Epoch 10/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5592 - accuracy: 0.8450
# Epoch 11/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5485 - accuracy: 0.8400
# Epoch 12/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5384 - accuracy: 0.8375
# Epoch 13/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5292 - accuracy: 0.8325
# Epoch 14/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5205 - accuracy: 0.8325
# Epoch 15/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5121 - accuracy: 0.8275
# Epoch 16/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5038 - accuracy: 0.8275
# Epoch 17/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4962 - accuracy: 0.8275
# Epoch 18/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4890 - accuracy: 0.8250
# Epoch 19/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4821 - accuracy: 0.8250
# Epoch 20/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4757 - accuracy: 0.8250
# Epoch 21/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4693 - accuracy: 0.8225
# Epoch 22/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4634 - accuracy: 0.8225
# Epoch 23/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4578 - accuracy: 0.8225
# Epoch 24/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4522 - accuracy: 0.8225
# Epoch 25/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4470 - accuracy: 0.8250
# Epoch 26/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4419 - accuracy: 0.8225
# Epoch 27/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4372 - accuracy: 0.8225
# Epoch 28/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4327 - accuracy: 0.8225
# Epoch 29/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4285 - accuracy: 0.8275
# Epoch 30/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4244 - accuracy: 0.8275
# Epoch 31/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4205 - accuracy: 0.8300
# Epoch 32/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4169 - accuracy: 0.8300
# Epoch 33/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4132 - accuracy: 0.8300
# Epoch 34/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4099 - accuracy: 0.8300
# Epoch 35/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4066 - accuracy: 0.8300
# Epoch 36/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4034 - accuracy: 0.8325
# Epoch 37/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4005 - accuracy: 0.8325
# Epoch 38/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3978 - accuracy: 0.8325
# Epoch 39/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3951 - accuracy: 0.8325
# Epoch 40/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3924 - accuracy: 0.8375
# Epoch 41/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3899 - accuracy: 0.8375
# Epoch 42/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.3874 - accuracy: 0.8375
# Epoch 43/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3850 - accuracy: 0.8375
# Epoch 44/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3827 - accuracy: 0.8375
# Epoch 45/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3807 - accuracy: 0.8375
# Epoch 46/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3786 - accuracy: 0.8375
# Epoch 47/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3766 - accuracy: 0.8375
# Epoch 48/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3749 - accuracy: 0.8375
# Epoch 49/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3728 - accuracy: 0.8375
# Epoch 50/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3710 - accuracy: 0.8375
# Epoch 51/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3694 - accuracy: 0.8375
# Epoch 52/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.8375
# Epoch 53/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3661 - accuracy: 0.8375
# Epoch 54/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3646 - accuracy: 0.8375
# Epoch 55/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.3630 - accuracy: 0.8375
# Epoch 56/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3616 - accuracy: 0.8375
# Epoch 57/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3602 - accuracy: 0.8375
# Epoch 58/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3590 - accuracy: 0.8425
# Epoch 59/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3576 - accuracy: 0.8425
# Epoch 60/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3564 - accuracy: 0.8450
# Epoch 61/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3551 - accuracy: 0.8425
# Epoch 62/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3540 - accuracy: 0.8450
# Epoch 63/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3529 - accuracy: 0.8450
# Epoch 64/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3518 - accuracy: 0.8450
# Epoch 65/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3507 - accuracy: 0.8450
# Epoch 66/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3496 - accuracy: 0.8450
# Epoch 67/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3486 - accuracy: 0.8450
# Epoch 68/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3477 - accuracy: 0.8450
# Epoch 69/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3468 - accuracy: 0.8450
# Epoch 70/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3458 - accuracy: 0.8450
# Epoch 71/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3448 - accuracy: 0.8450
# Epoch 72/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3440 - accuracy: 0.8450
# Epoch 73/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3431 - accuracy: 0.8450
# Epoch 74/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3422 - accuracy: 0.8450
# Epoch 75/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3413 - accuracy: 0.8450
# Epoch 76/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3404 - accuracy: 0.8475
# Epoch 77/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3397 - accuracy: 0.8475
# Epoch 78/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3389 - accuracy: 0.8475
# Epoch 79/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3381 - accuracy: 0.8500
# Epoch 80/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3373 - accuracy: 0.8475
# Epoch 81/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3365 - accuracy: 0.8475
# Epoch 82/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3358 - accuracy: 0.8500
# Epoch 83/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3351 - accuracy: 0.8500
# Epoch 84/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3342 - accuracy: 0.8500
# Epoch 85/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3335 - accuracy: 0.8500
# Epoch 86/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3328 - accuracy: 0.8500
# Epoch 87/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3321 - accuracy: 0.8500
# Epoch 88/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3313 - accuracy: 0.8500
# Epoch 89/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3306 - accuracy: 0.8500
# Epoch 90/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3299 - accuracy: 0.8500
# Epoch 91/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3293 - accuracy: 0.8500
# Epoch 92/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3287 - accuracy: 0.8500
# Epoch 93/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3280 - accuracy: 0.8500
# Epoch 94/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3273 - accuracy: 0.8500
# Epoch 95/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3268 - accuracy: 0.8500
# Epoch 96/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3261 - accuracy: 0.8500
# Epoch 97/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3255 - accuracy: 0.8500
# Epoch 98/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.8500
# Epoch 99/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3243 - accuracy: 0.8525
# Epoch 100/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3236 - accuracy: 0.8525
# Epoch 101/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.8525
# Epoch 102/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3225 - accuracy: 0.8525
# Epoch 103/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3219 - accuracy: 0.8525
# Epoch 104/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3214 - accuracy: 0.8525
# Epoch 105/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3208 - accuracy: 0.8525
# Epoch 106/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3203 - accuracy: 0.8525
# Epoch 107/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3198 - accuracy: 0.8525
# Epoch 108/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3193 - accuracy: 0.8525
# Epoch 109/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3187 - accuracy: 0.8525
# Epoch 110/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3182 - accuracy: 0.8525
# Epoch 111/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3177 - accuracy: 0.8525
# Epoch 112/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3172 - accuracy: 0.8525
# Epoch 113/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3168 - accuracy: 0.8550
# Epoch 114/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3164 - accuracy: 0.8525
# Epoch 115/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3159 - accuracy: 0.8550
# Epoch 116/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3154 - accuracy: 0.8550
# Epoch 117/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3151 - accuracy: 0.8550
# Epoch 118/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.8550
# Epoch 119/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3142 - accuracy: 0.8575
# Epoch 120/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3137 - accuracy: 0.8550
# Epoch 121/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3133 - accuracy: 0.8550
# Epoch 122/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3128 - accuracy: 0.8575
# Epoch 123/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3123 - accuracy: 0.8575
# Epoch 124/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3120 - accuracy: 0.8575
# Epoch 125/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3116 - accuracy: 0.8575
# Epoch 126/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.8575
# Epoch 127/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3108 - accuracy: 0.8575
# Epoch 128/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3105 - accuracy: 0.8575
# Epoch 129/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3100 - accuracy: 0.8575
# Epoch 130/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3096 - accuracy: 0.8575
# Epoch 131/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3093 - accuracy: 0.8600
# Epoch 132/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3089 - accuracy: 0.8600
# Epoch 133/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3085 - accuracy: 0.8600
# Epoch 134/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3082 - accuracy: 0.8575
# Epoch 135/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3077 - accuracy: 0.8600
# Epoch 136/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3073 - accuracy: 0.8600
# Epoch 137/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.8600
# Epoch 138/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.8600
# Epoch 139/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3063 - accuracy: 0.8600
# Epoch 140/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.8600
# Epoch 141/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3056 - accuracy: 0.8600
# Epoch 142/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3053 - accuracy: 0.8600
# Epoch 143/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3050 - accuracy: 0.8600
# Epoch 144/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3047 - accuracy: 0.8600
# Epoch 145/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3043 - accuracy: 0.8600
# Epoch 146/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3040 - accuracy: 0.8600
# Epoch 147/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3037 - accuracy: 0.8600
# Epoch 148/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.8600
# Epoch 149/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.8600
# Epoch 150/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3029 - accuracy: 0.8600
# Epoch 151/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3026 - accuracy: 0.8600
# Epoch 152/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3024 - accuracy: 0.8600
# Epoch 153/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3020 - accuracy: 0.8600
# Epoch 154/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3018 - accuracy: 0.8600
# Epoch 155/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3015 - accuracy: 0.8600
# Epoch 156/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3013 - accuracy: 0.8600
# Epoch 157/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3012 - accuracy: 0.8600
# Epoch 158/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3008 - accuracy: 0.8625
# Epoch 159/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.8600
# Epoch 160/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3003 - accuracy: 0.8600
# Epoch 161/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3000 - accuracy: 0.8600
# Epoch 162/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2997 - accuracy: 0.8625
# Epoch 163/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2995 - accuracy: 0.8625
# Epoch 164/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2993 - accuracy: 0.8625
# Epoch 165/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8650
# Epoch 166/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.8625
# Epoch 167/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8650
# Epoch 168/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2984 - accuracy: 0.8650
# Epoch 169/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2981 - accuracy: 0.8650
# Epoch 170/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2979 - accuracy: 0.8650
# Epoch 171/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2977 - accuracy: 0.8625
# Epoch 172/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.8650
# Epoch 173/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2973 - accuracy: 0.8675
# Epoch 174/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8675
# Epoch 175/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2969 - accuracy: 0.8675
# Epoch 176/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2966 - accuracy: 0.8675
# Epoch 177/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2965 - accuracy: 0.8675
# Epoch 178/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.8650
# Epoch 179/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2961 - accuracy: 0.8650
# Epoch 180/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2960 - accuracy: 0.8675
# Epoch 181/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2958 - accuracy: 0.8650
# Epoch 182/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2956 - accuracy: 0.8650
# Epoch 183/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2954 - accuracy: 0.8675
# Epoch 184/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2952 - accuracy: 0.8650
# Epoch 185/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2950 - accuracy: 0.8650
# Epoch 186/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2948 - accuracy: 0.8650
# Epoch 187/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2948 - accuracy: 0.8650
# Epoch 188/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2944 - accuracy: 0.8675
# Epoch 189/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2943 - accuracy: 0.8650
# Epoch 190/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.8675
# Epoch 191/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2940 - accuracy: 0.8675
# Epoch 192/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2938 - accuracy: 0.8675
# Epoch 193/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.8675
# Epoch 194/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2935 - accuracy: 0.8675
# Epoch 195/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2933 - accuracy: 0.8675
# Epoch 196/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2931 - accuracy: 0.8675
# Epoch 197/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2930 - accuracy: 0.8675
# Epoch 198/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.8675
# Epoch 199/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.8675
# Epoch 200/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2925 - accuracy: 0.8675
# Epoch 201/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2924 - accuracy: 0.8675
# Epoch 202/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2924 - accuracy: 0.8675
# Epoch 203/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2922 - accuracy: 0.8675
# Epoch 204/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2920 - accuracy: 0.8675
# Epoch 205/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2918 - accuracy: 0.8675
# Epoch 206/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2918 - accuracy: 0.8675
# Epoch 207/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2916 - accuracy: 0.8625
# Epoch 208/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2915 - accuracy: 0.8625
# Epoch 209/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2913 - accuracy: 0.8650
# Epoch 210/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2912 - accuracy: 0.8625
# Epoch 211/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2911 - accuracy: 0.8650
# Epoch 212/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2909 - accuracy: 0.8625
# Epoch 213/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2908 - accuracy: 0.8625
# Epoch 214/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.8625
# Epoch 215/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2906 - accuracy: 0.8625
# Epoch 216/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2905 - accuracy: 0.8625
# Epoch 217/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2903 - accuracy: 0.8625
# Epoch 218/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.8625
# Epoch 219/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2901 - accuracy: 0.8625
# Epoch 220/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.8625
# Epoch 221/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2899 - accuracy: 0.8625
# Epoch 222/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2897 - accuracy: 0.8625
# Epoch 223/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2896 - accuracy: 0.8625
# Epoch 224/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2896 - accuracy: 0.8625
# Epoch 225/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2894 - accuracy: 0.8625
# Epoch 226/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2893 - accuracy: 0.8625
# Epoch 227/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2891 - accuracy: 0.8625
# Epoch 228/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2891 - accuracy: 0.8625
# Epoch 229/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2890 - accuracy: 0.8625
# Epoch 230/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2889 - accuracy: 0.8625
# Epoch 231/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2888 - accuracy: 0.8625
# Epoch 232/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2887 - accuracy: 0.8625
# Epoch 233/300
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2886 - accuracy: 0.8625
# Epoch 234/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2884 - accuracy: 0.8625
# Epoch 235/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2884 - accuracy: 0.8625
# Epoch 236/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2882 - accuracy: 0.8625
# Epoch 237/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2882 - accuracy: 0.8625
# Epoch 238/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2880 - accuracy: 0.8625
# Epoch 239/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2880 - accuracy: 0.8625
# Epoch 240/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2879 - accuracy: 0.8625
# Epoch 241/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2877 - accuracy: 0.8625
# Epoch 242/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2876 - accuracy: 0.8625
# Epoch 243/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2876 - accuracy: 0.8625
# Epoch 244/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8625
# Epoch 245/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2874 - accuracy: 0.8625
# Epoch 246/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2873 - accuracy: 0.8625
# Epoch 247/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2872 - accuracy: 0.8625
# Epoch 248/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.8625
# Epoch 249/300
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2870 - accuracy: 0.8625
# Epoch 250/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2870 - accuracy: 0.8625
# Epoch 251/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.8625
# Epoch 252/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.8625
# Epoch 253/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.8625
# Epoch 254/300
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2867 - accuracy: 0.8625
# Epoch 255/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2864 - accuracy: 0.8625
# Epoch 256/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2865 - accuracy: 0.8625
# Epoch 257/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2864 - accuracy: 0.8625
# Epoch 258/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2863 - accuracy: 0.8625
# Epoch 259/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2861 - accuracy: 0.8625
# Epoch 260/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2861 - accuracy: 0.8625
# Epoch 261/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2860 - accuracy: 0.8625
# Epoch 262/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2860 - accuracy: 0.8625
# Epoch 263/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.8625
# Epoch 264/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.8625
# Epoch 265/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.8625
# Epoch 266/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2855 - accuracy: 0.8650
# Epoch 267/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2855 - accuracy: 0.8650
# Epoch 268/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2855 - accuracy: 0.8650
# Epoch 269/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2853 - accuracy: 0.8650
# Epoch 270/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2852 - accuracy: 0.8625
# Epoch 271/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2852 - accuracy: 0.8650
# Epoch 272/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.8650
# Epoch 273/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.8650
# Epoch 274/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2850 - accuracy: 0.8650
# Epoch 275/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2849 - accuracy: 0.8650
# Epoch 276/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8650
# Epoch 277/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8650
# Epoch 278/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2847 - accuracy: 0.8650
# Epoch 279/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2848 - accuracy: 0.8650
# Epoch 280/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2845 - accuracy: 0.8650
# Epoch 281/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2844 - accuracy: 0.8650
# Epoch 282/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2843 - accuracy: 0.8650
# Epoch 283/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2842 - accuracy: 0.8650
# Epoch 284/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2842 - accuracy: 0.8650
# Epoch 285/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2841 - accuracy: 0.8650
# Epoch 286/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.8650
# Epoch 287/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.8650
# Epoch 288/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.8650
# Epoch 289/300
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2839 - accuracy: 0.8650
# Epoch 290/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2837 - accuracy: 0.8650
# Epoch 291/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2836 - accuracy: 0.8650
# Epoch 292/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2836 - accuracy: 0.8650
# Epoch 293/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2836 - accuracy: 0.8675
# Epoch 294/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2834 - accuracy: 0.8650
# Epoch 295/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2835 - accuracy: 0.8650
# Epoch 296/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2833 - accuracy: 0.8650
# Epoch 297/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2832 - accuracy: 0.8650
# Epoch 298/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2832 - accuracy: 0.8675
# Epoch 299/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.8675
# Epoch 300/300
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.8675

# %% [markdown]
# Use the following code to plot the progress of accurarcy and loss while training the model.

# %%
plt.figure(figsize=(10,8))
plt.plot(hist.history['accuracy'], label='Accuracy')
plt.plot(hist.history['loss'], label='Loss')
plt.legend(loc='best')
plt.title('Training Accuracy and Loss')
plt.show()

# %% [markdown]
# Lookup the `evaluate()` function in the [documentation](https://keras.io/api/models/model_training_apis/) so you can use it to calculate the loss and accuracy of your model on the test set.

# %%
results = model.evaluate(X_test, Y_test, batch_size=len(Y_test))
print("Test Loss: %.3f\nTest Accuracy: %.3f" %(results[0], results[1]))
# Out:
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2715 - accuracy: 0.8900
# Test Loss: 0.271
# Test Accuracy: 0.890

# %% [markdown]
# With the function `plot_decision_boundary()` you can visualize the decision boundary that the model learned.
#
# The decision boundary indicates how to decide to which class each data point belongs.

# %%
def plot_decision_boundary(prediction_model, X, Y):
    # Plot the decision boundary
    # Determine grid range in x and y directions
    x_min, x_max = X[:, 0].min()-0.1, X[:, 0].max()+0.1
    y_min, y_max = X[:, 1].min()-0.1, X[:, 1].max()+0.1

    # Set grid spacing parameter
    spacing = min(x_max - x_min, y_max - y_min) / 100

    # Create grid
    XX, YY = np.meshgrid(np.arange(x_min, x_max, spacing),
                   np.arange(y_min, y_max, spacing))

    # Concatenate data to match input
    data = np.hstack((XX.ravel().reshape(-1,1),
                      YY.ravel().reshape(-1,1)))
    # Get decision boundary probabilities
    db_prob = prediction_model.predict(data)

    # Convert probabilities to classes
    clf = np.where(db_prob<0.5,0,1)

    Z = clf.reshape(XX.shape)

    plt.figure(figsize=(10,8))
    plt.contourf(XX, YY, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(X[:,0], X[:,1], c=Y,
                cmap=plt.cm.Spectral)
    plt.show()

# %%
plot_decision_boundary(model, X, Y)
# Out:
# 432/432 [==============================] - 1s 1ms/step
